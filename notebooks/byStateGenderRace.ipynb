# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import plotly
import cufflinks as cf

# %%
df = pd.read_csv('data/StateGenderYr.csv')

# %%
df.head()
# Out:
#    Notes  Year  Year Code                              Race Race Code  \
# 0    NaN  1999       1999  American Indian or Alaska Native    1002-5
# 1    NaN  1999       1999  American Indian or Alaska Native    1002-5
# 2    NaN  1999       1999  American Indian or Alaska Native    1002-5
# 3    NaN  1999       1999  American Indian or Alaska Native    1002-5
# 4    NaN  1999       1999  American Indian or Alaska Native    1002-5
#
#         State  State Code  Gender Gender Code Deaths  Population  \
# 0     Alabama           1  Female           F     24       11411
# 1      Alaska           2  Female           F    293       52608
# 2     Arizona           4  Female           F    704      140372
# 3    Arkansas           5  Female           F     19        9138
# 4  California           6  Female           F    411      225050
#
#          Crude Rate
# 0            210.32
# 1            556.95
# 2            501.52
# 3  207.922959072007
# 4            182.63

# %%
df.isnull().sum()
# Out:
# Notes          4284
# Year              0
# Year Code         0
# Race              0
# Race Code         0
# State             0
# State Code        0
# Gender            0
# Gender Code       0
# Deaths            0
# Population        0
# Crude Rate        0
# dtype: int64

# %%
df.drop(columns=['Notes'], inplace=True)

# %%
df.Deaths.value_counts()
# Out:
# Suppressed    284
# 27             39
# 10             38
# 17             30
# 12             30
#              ...
# 1215            1
# 7381            1
# 2117            1
# 1224            1
# 10133           1
# Name: Deaths, Length: 2265, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         4284 non-null   int64
#  1   Year Code    4284 non-null   int64
#  2   Race         4284 non-null   object
#  3   Race Code    4284 non-null   object
#  4   State        4284 non-null   object
#  5   State Code   4284 non-null   int64
#  6   Gender       4284 non-null   object
#  7   Gender Code  4284 non-null   object
#  8   Deaths       4284 non-null   object
#  9   Population   4284 non-null   int64
#  10  Crude Rate   4284 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 368.3+ KB

# %%
df.drop(columns=['Year Code', 'Race Code', 'State Code', 'Gender Code'], inplace=True)

# %%
df.Population.sum()
# Out:
# 3261775883

# %%
suppressed = df.loc[df['Deaths'] == 'Suppressed']
suppressed.info()
suppressed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 6 to 4208
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        284 non-null    int64
#  1   Race        284 non-null    object
#  2   State       284 non-null    object
#  3   Gender      284 non-null    object
#  4   Deaths      284 non-null    object
#  5   Population  284 non-null    int64
#  6   Crude Rate  284 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 17.8+ KB
#       Year                              Race                 State  Gender  \
# 6     1999  American Indian or Alaska Native           Connecticut  Female
# 7     1999  American Indian or Alaska Native              Delaware  Female
# 8     1999  American Indian or Alaska Native  District of Columbia  Female
# 17    1999  American Indian or Alaska Native              Kentucky  Female
# 29    1999  American Indian or Alaska Native         New Hampshire  Female
# ...    ...                               ...                   ...     ...
# 4091  2019  American Indian or Alaska Native                Hawaii  Female
# 4109  2019  American Indian or Alaska Native         New Hampshire  Female
# 4125  2019  American Indian or Alaska Native               Vermont  Female
# 4128  2019  American Indian or Alaska Native         West Virginia  Female
# 4208  2019         Black or African American               Montana  Female
#
#           Deaths  Population  Crude Rate
# 6     Suppressed        5751  Suppressed
# 7     Suppressed        1587  Suppressed
# 8     Suppressed        1128  Suppressed
# 17    Suppressed        3292  Suppressed
# 29    Suppressed        1553  Suppressed
# ...          ...         ...         ...
# 4091  Suppressed        3052  Suppressed
# 4109  Suppressed        2483  Suppressed
# 4125  Suppressed        1573  Suppressed
# 4128  Suppressed        2223  Suppressed
# 4208  Suppressed        4553  Suppressed
#
# [284 rows x 7 columns]

# %%
df1 = df.groupby(['Year', "Race"]).sum()

# %% [markdown]
# #### Total Population for each Race

# %%
df1
# Out:
#                                        Population
# Year Race
# 1999 American Indian or Alaska Native     1421980
#      Asian or Pacific Islander            5845369
#      Black or African American           18978030
#      White                              115991916
# 2000 American Indian or Alaska Native     1496044
# ...                                           ...
# 2018 White                              128385028
# 2019 American Indian or Alaska Native     2387147
#      Asian or Pacific Islander           11350332
#      Black or African American           24220575
#      White                              128624145
#
# [84 rows x 1 columns]

# %%
check = df1.groupby(['Year'])['Population'].sum()
check
# Out:
# Year
# 1999    142237295
# 2000    143368343
# 2001    145077463
# 2002    146394634
# 2003    147679036
# 2004    148977286
# 2005    150319521
# 2006    151732647
# 2007    153166353
# 2008    154604015
# 2009    155964075
# 2010    156964212
# 2011    158301098
# 2012    159421973
# 2013    160477237
# 2014    161920569
# 2015    163189523
# 2016    164048590
# 2017    165311059
# 2018    166038755
# 2019    166582199
# Name: Population, dtype: int64

# %%
df1
# Out:
#                                        Population  Total Pop
# Year Race
# 1999 American Indian or Alaska Native     1421980    1421980
#      Asian or Pacific Islander            5845369    5845369
#      Black or African American           18978030   18978030
#      White                              115991916  115991916
# 2000 American Indian or Alaska Native     1496044    1496044
# ...                                           ...        ...
# 2018 White                              128385028  128385028
# 2019 American Indian or Alaska Native     2387147    2387147
#      Asian or Pacific Islander           11350332   11350332
#      Black or African American           24220575   24220575
#      White                              128624145  128624145
#
# [84 rows x 2 columns]

# %%
suppressed.Race.value_counts()
# Out:
# American Indian or Alaska Native    133
# Black or African American            79
# Asian or Pacific Islander            72
# Name: Race, dtype: int64

# %%
df.Race.value_counts().sum()
# Out:
# 4284

# %%
df['Crude Rate'].replace(to_replace = {'Suppressed': np.nan}, inplace=True)

# %%
df['Crude Rate'] = df['Crude Rate'].astype(float)

# %%
df['Crude Rate'].argmin(), df['Crude Rate'].argmax()
# Out:
# (3702, 150)

# %%
df.iloc[150]
# Out:
# Year                                1999
# Year Code                           1999
# Race           Black or African American
# Race Code                         2054-5
# State                      West Virginia
# State Code                            54
# Gender                            Female
# Gender Code                            F
# Deaths                               383
# Population                         29770
# Crude Rate                       1286.53
# Name: 150, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         4284 non-null   int64
#  1   Year Code    4284 non-null   int64
#  2   Race         4284 non-null   object
#  3   Race Code    4284 non-null   object
#  4   State        4284 non-null   object
#  5   State Code   4284 non-null   int64
#  6   Gender       4284 non-null   object
#  7   Gender Code  4284 non-null   object
#  8   Deaths       4284 non-null   object
#  9   Population   4284 non-null   int64
#  10  Crude Rate   4000 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 368.3+ KB

# %%
df2 = df.drop(columns=['Year Code', 'Race Code', 'State Code', 'Gender'])

# %%
df3 = df[df.Deaths != 'Suppressed']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 4283
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         4000 non-null   int64
#  1   Year Code    4000 non-null   int64
#  2   Race         4000 non-null   object
#  3   Race Code    4000 non-null   object
#  4   State        4000 non-null   object
#  5   State Code   4000 non-null   int64
#  6   Gender       4000 non-null   object
#  7   Gender Code  4000 non-null   object
#  8   Deaths       4000 non-null   object
#  9   Population   4000 non-null   int64
#  10  Crude Rate   4000 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 375.0+ KB

# %%
df3.drop(['Year Code'], axis=1, inplace=True)

# %%
yr_df = df3.groupby('Year')

# %%
df3['Year'].unique()
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
df3.Year = df3.Year.astype(int)

# %%
# df["Crude Rate"].iplot(kind="histogram", bins=20, theme="white", title="Passenger's Ages", xTitle='Ages', yTitle='Count')

# %%
yr = df3.groupby(['Year Code'])['Crude Rate'].mean()

# %%
pal = sns.color_palette("Blues")
print(pal.as_hex())
# Out:
# ['#dbe9f6', '#bad6eb', '#89bedc', '#539ecd', '#2b7bba', '#0b559f']

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(data = yr, ax=ax, color='#89bedc')
plt.title('Average Crude Death Rate Across All States (per 100,000) by Year')
plt.xlabel('Year')
plt.ylabel('Crude Rate (deaths per 100,000)')
# Out:
# Text(0, 0.5, 'Crude Rate (deaths per 100,000)')

# %%
yr.head()
# Out:
# Year Code
# 1999    546.464740
# 2000    544.781348
# 2001    535.360938
# 2002    540.825654
# 2003    542.032087
# Name: Crude Rate, dtype: float64

# %%
df3['Year'] = pd.to_datetime(df3['Year'], format='%Y', unit='Y')

# %%
df3.Race.unique()
# Out:
# array(['American Indian or Alaska Native', 'Asian or Pacific Islander',
#        'Black or African American', 'White'], dtype=object)

# %%
race = ['American Indian or Alaska Native', 'Asian or Pacific Islander',
       'Black or African American', 'White']
df_me = df3.loc[df3['Race'].isin(race)]
df_me

df_me.groupby(['Race', 'Year'])['Crude Rate'].mean().plot()
# Out:
# <AxesSubplot:xlabel='Race,Year'>

# %%
fig, ax = plt.subplots(figsize=(14, 5))
df_me.groupby(['Year', 'Race'])['Crude Rate'].mean().unstack().plot(ax=ax)  
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='Line', loc='upper left')
ax.set_title('Trends in Crude Rate (deaths per 100,000) by Race')
ax.set_ylabel('Crude Rate (deaths per 100,000)');

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 4283
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         4000 non-null   datetime64[ns]
#  1   Year Code    4000 non-null   int64
#  2   Race         4000 non-null   object
#  3   Race Code    4000 non-null   object
#  4   State        4000 non-null   object
#  5   State Code   4000 non-null   int64
#  6   Gender       4000 non-null   object
#  7   Gender Code  4000 non-null   object
#  8   Deaths       4000 non-null   object
#  9   Population   4000 non-null   int64
#  10  Crude Rate   4000 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 375.0+ KB

# %%
df3.drop(columns=['Year Code', 'Race Code', 'State Code', 'Gender'], inplace=True)

# %%
df3.head(50)
# Out:
#          Year                              Race           State Gender Code  \
# 0  1999-01-01  American Indian or Alaska Native         Alabama           F
# 1  1999-01-01  American Indian or Alaska Native          Alaska           F
# 2  1999-01-01  American Indian or Alaska Native         Arizona           F
# 3  1999-01-01  American Indian or Alaska Native        Arkansas           F
# 4  1999-01-01  American Indian or Alaska Native      California           F
# 5  1999-01-01  American Indian or Alaska Native        Colorado           F
# 9  1999-01-01  American Indian or Alaska Native         Florida           F
# 10 1999-01-01  American Indian or Alaska Native         Georgia           F
# 11 1999-01-01  American Indian or Alaska Native          Hawaii           F
# 12 1999-01-01  American Indian or Alaska Native           Idaho           F
# 13 1999-01-01  American Indian or Alaska Native        Illinois           F
# 14 1999-01-01  American Indian or Alaska Native         Indiana           F
# 15 1999-01-01  American Indian or Alaska Native            Iowa           F
# 16 1999-01-01  American Indian or Alaska Native          Kansas           F
# 18 1999-01-01  American Indian or Alaska Native       Louisiana           F
# 19 1999-01-01  American Indian or Alaska Native           Maine           F
# 20 1999-01-01  American Indian or Alaska Native        Maryland           F
# 21 1999-01-01  American Indian or Alaska Native   Massachusetts           F
# 22 1999-01-01  American Indian or Alaska Native        Michigan           F
# 23 1999-01-01  American Indian or Alaska Native       Minnesota           F
# 24 1999-01-01  American Indian or Alaska Native     Mississippi           F
# 25 1999-01-01  American Indian or Alaska Native        Missouri           F
# 26 1999-01-01  American Indian or Alaska Native         Montana           F
# 27 1999-01-01  American Indian or Alaska Native        Nebraska           F
# 28 1999-01-01  American Indian or Alaska Native          Nevada           F
# 30 1999-01-01  American Indian or Alaska Native      New Jersey           F
# 31 1999-01-01  American Indian or Alaska Native      New Mexico           F
# 32 1999-01-01  American Indian or Alaska Native        New York           F
# 33 1999-01-01  American Indian or Alaska Native  North Carolina           F
# 34 1999-01-01  American Indian or Alaska Native    North Dakota           F
# 35 1999-01-01  American Indian or Alaska Native            Ohio           F
# 36 1999-01-01  American Indian or Alaska Native        Oklahoma           F
# 37 1999-01-01  American Indian or Alaska Native          Oregon           F
# 38 1999-01-01  American Indian or Alaska Native    Pennsylvania           F
# 39 1999-01-01  American Indian or Alaska Native    Rhode Island           F
# 40 1999-01-01  American Indian or Alaska Native  South Carolina           F
# 41 1999-01-01  American Indian or Alaska Native    South Dakota           F
# 42 1999-01-01  American Indian or Alaska Native       Tennessee           F
# 43 1999-01-01  American Indian or Alaska Native           Texas           F
# 44 1999-01-01  American Indian or Alaska Native            Utah           F
# 46 1999-01-01  American Indian or Alaska Native        Virginia           F
# 47 1999-01-01  American Indian or Alaska Native      Washington           F
# 49 1999-01-01  American Indian or Alaska Native       Wisconsin           F
# 50 1999-01-01  American Indian or Alaska Native         Wyoming           F
# 51 1999-01-01         Asian or Pacific Islander         Alabama           F
# 52 1999-01-01         Asian or Pacific Islander          Alaska           F
# 53 1999-01-01         Asian or Pacific Islander         Arizona           F
# 54 1999-01-01         Asian or Pacific Islander        Arkansas           F
# 55 1999-01-01         Asian or Pacific Islander      California           F
# 56 1999-01-01         Asian or Pacific Islander        Colorado           F
#
#    Deaths  Population  Crude Rate
# 0      24       11411  210.320000
# 1     293       52608  556.950000
# 2     704      140372  501.520000
# 3      19        9138  207.922959
# 4     411      225050  182.630000
# 5      56       26101  214.550000
# 9      59       29353  201.000000
# 10     37       10010  369.630000
# 11     10        2183  458.085204
# 12     38        9750  389.740000
# 13     30       19620  152.910000
# 14     17        8277  205.388426
# 15     18        4369  411.993591
# 16     63       14211  443.320000
# 18     30       12911  232.360000
# 19     27        3899  692.490000
# 20     29        9299  311.860000
# 21     17        9899  171.734519
# 22    195       36102  540.140000
# 23    157       30207  519.750000
# 24     29        5383  538.730000
# 25     46       13840  332.370000
# 26    175       29417  594.890000
# 27     74        7882  938.850000
# 28     56       15325  365.420000
# 30     27       13166  205.070000
# 31    404       92200  438.180000
# 32     93       57467  161.830000
# 33    282       51555  546.990000
# 34     99       16018  618.050000
# 35     28       14812  189.040000
# 36    750      156762  478.430000
# 37     90       27716  324.720000
# 38     21       10674  196.740000
# 39     14        3224  434.243176
# 40     14        6818  205.338809
# 41    204       32087  635.770000
# 42     12        6930  173.160173
# 43     50       66527   75.160000
# 44     59       16303  361.900000
# 46     31       10711  289.420000
# 47    245       55415  442.120000
# 49    125       25441  491.330000
# 50     27        5828  463.280000
# 51     29       17708  163.770000
# 52     41       15912  257.670000
# 53    107       57819  185.060000
# 54     18       11295  159.362550
# 55   6533     2097682  311.440000
# 56    126       56422  223.320000
